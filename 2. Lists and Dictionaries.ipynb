# %% [markdown]
# # Homework: Lists and Dictionaries

# %% [markdown]
# ## Task 1

# %%
temperatures = [22, 25, 19, 23, 26, 20, 21, 22]
print(temperatures[0])
print(temperatures[-1])
temperatures.append(24)
temperatures.remove(19)
print(len(temperatures))
print(sum(temperatures))
print(max(temperatures))
# Out:
# 22
# 22
# 8
# 183
# 26

# %% [markdown]
# ## Task 2

# %%
data = {
    "name": "Marta",
    "age": 22,
    "city": "Olomouc"
}

# %%
print(data["name"])
# Out:
# Marta

# %%
data["age"] = 21
print(data["age"])
# Out:
# 21

# %%
data["hobby"] = "programming"
print(data)
# Out:
# {'name': 'Marta', 'age': 21, 'city': 'Olomouc', 'hobby': 'programming'}

# %%
print(data.keys())
print(data.values())
# Out:
# dict_keys(['name', 'age', 'city', 'hobby'])
# dict_values(['Marta', 21, 'Olomouc', 'programming'])

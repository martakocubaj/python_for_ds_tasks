# %% [markdown]
# # Homework: the for loop

# %% [markdown]
# ## Task 1

# %%
for i in range(1,8):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# ## Task 2

# %%
names = ["Олег", "Анна", "Іван", "Марія"]

for i in names:
    print(f"Привіт, {i}!")
# Out:
# Привіт, Олег!
# Привіт, Анна!
# Привіт, Іван!
# Привіт, Марія!

# %% [markdown]
# ## Task 3

# %%
grades = [85, 92, 78, 95, 88]

for i, grade in enumerate(grades):
    print(f"Студент {i+1}: {grade} балів")
# Out:
# Студент 1: 85 балів
# Студент 2: 92 балів
# Студент 3: 78 балів
# Студент 4: 95 балів
# Студент 5: 88 балів

# %% [markdown]
# ## Task 4

# %%
suma = 0
for i in range(2, 21, 2):
    suma += i
        
print(suma)
# Out:
# 110

# %% [markdown]
# # My first homework in Python

# %% [markdown]
# ## Task 1

# %%
name = 'Marta'
age = 21
height = 1.73
is_student = True

# %%
print(f"My name is {name}")
print(f"I`m {age}")
print(f"My height is {height}")
if is_student:  
    print("I'm a student")
else:
    print("I'm not a student")
# Out:
# My name is Marta
# I`m 21
# My height is 1.73
# I'm a student

# %% [markdown]
# ## Task 2

# %%
var1 = 15
var2 = 4
suma = var1 + var2
print(f"Sum: {suma}")
dif = var1 - var2
print(f"Difference: {dif}")
product = var1 * var2
print(f"Product: {product}")
division = var1 / var2
print(f"Division: {division}")
floor_division = var1 // var2
print(f"Floor divivsion: {floor_division}")
modulo = var1 % var2
print(f"Modulo: {modulo}")
power = var1 ** var2
print(f"Power: {power}")
# Out:
# Sum: 19
# Difference: 11
# Product: 60
# Division: 3.75
# Floor divivsion: 3
# Modulo: 3
# Power: 50625

# %% [markdown]
# ## Task 3

# %%
last_name = "Kochubai"
full_name = f"{name} {last_name}"
print(f"My full name is {full_name}")
print(full_name.upper())
print(full_name.lower())
print(len(full_name))
print(f"My name is {full_name}, I`m {age}.")
# Out:
# My full name is Marta Kochubai
# MARTA KOCHUBAI
# marta kochubai
# 14
# My name is Marta Kochubai, I`m 21.
